# %%
import numpy as np
import torch

# %%
data = [[1, 2,3], [3, 4,5],[6,7,8]]
tensor = torch.tensor(data)
# We move our tensor to the current accelerator if available
if torch.accelerator.is_available():
    tensor = tensor.to(torch.accelerator.current_accelerator())

# %%
print(tensor)
print(tensor[:, :])
# Out:
# tensor([[1, 2, 3],
#         [3, 4, 5],
#         [6, 7, 8]], device='cuda:0')
# tensor([[1, 2, 3],
#         [3, 4, 5],
#         [6, 7, 8]], device='cuda:0')

# %%
new = torch.cat([tensor ,  tensor  ], dim = 1)
print(new.shape)
# Out:
# torch.Size([3, 6])
